# %%
import requests

r = requests.get("https://data.gcis.nat.gov.tw/od/data/api/424C33E1-BB11-48D1-94D5-D4DD89DC940D?$format=json&$filter=Business_Item eq CC01080&$skip=0&$top=1000", verify=False)
print(r.status_code)
# Out:
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200

# %%
import requests

r = requests.get("https://data.gcis.nat.gov.tw/od/data/api/424C33E1-BB11-48D1-94D5-D4DD89DC940D?$format=json&$filter=Business_Item eq CC01080&$skip=0&$top=1000")

print(r)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-43-88cfc30cda53> in <module>
#       2
#       3 r = requests.get("https://data.gcis.nat.gov.tw/od/data/api/424C33E1-BB11-48D1-94D5-D4DD89DC940D?$format=json&$filter=Business_Item eq CC01080&$skip=0&$top=1000")
# ----> 4 a=r.json()
#       5 print(a)
#
# //anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# //anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
import pandas as pd

# %%
for i in list_of_dicts:
    print(i['Business_Accounting_NO'],i['Company_Name'],i['Capital_Stock_Amount'])
# Out:
# 00003219 大順輪船股份有限公司 10000000
# 00005700 大中福國企業有限公司 20000000
# 00011203 大同通運股份有限公司 51840000
# 00021407 上海煤氣有限公司 10000000
# 00026901 利恩交通股份有限公司 25000000
# 00031209 大德建設股份有限公司 28800000
# 00035176 太隆實業股份有限公司 28000000
# 00048406 中美汽車有限公司 12600000
# 00061717 中台通運股份有限公司 20000000
# 00063406 中福汽車貨運股份有限公司 10000000
# 00067607 友聯汽車貨運股份有限公司 38000000
# 00069801 友駿營造工程股份有限公司 65000000
# 00087006 永徠交通股份有限公司 25000000
# 00090706 立達汽車貨運股份有限公司 13000000
# 00093008 正達汽車貨運股份有限公司 29000000
# 00099636 正揚汽車貨運股份有限公司 15000000
# 00103408 自立鐵工廠股份有限公司 20000000
# 00121406 安達汽車貨運股份有限公司 29800000
# 00145976 聯成航業股份有限公司 28000000
# 00160202 上亞通運股份有限公司 13000000
# 00172002 和泰汽車貨運股份有限公司 15000000
# 00198143 洋豐投資股份有限公司 30000000
# 00199038 建成裕製機工業有限公司 10000000
# 00199276 帝王大飯店有限公司 40000000
# 00225107 碩山交通股份有限公司 25000000
# 00242909 順峰汽車貨運有限公司 10000000
# 00261601 基水食品股份有限公司 20000000
# 00263087 達祥電機有限公司 10000000
# 00263609 德記通運股份有限公司 15000000
# 00273206 員宏交通事業股份有限公司 25000000
# 00287308 利記企業股份有限公司 10000000
# ...

# %%
import requests
import pandas as pd
import json

r = requests.get("https://data.gcis.nat.gov.tw/od/data/api/F0E8FB8D-E2FD-472E-886C-91C673641F31?$format=json&$filter=Company_Status eq 01 and Capital_Stock_Amount eq F&$skip=0&$top=1000", verify=False)
list_of_dicts = r.json()
Business_Accounting_NO = [i['Business_Accounting_NO'] for i in list_of_dicts]  
Company_Name = [i['Company_Name'] for i in list_of_dicts]
Capital_Stock_Amount = [i['Capital_Stock_Amount'] for i in list_of_dicts]
aqi_dict = {
    'Business_Accounting_NO': Business_Accounting_NO,
    'Company_Name': Company_Name,
    'Capital_Stock_Amount': Capital_Stock_Amount
}
df = pd.DataFrame(aqi_dict)
df.to_csv("aqi.csv", index=False)
with open("aqi.json", "w") as f:
    json.dump(aqi_dict, f, ensure_ascii=False)
# Out:
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
