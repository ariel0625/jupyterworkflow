# %% [markdown]
# ## Homework_1 Chen Hsin Lee
#
#
# * bicycle_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/leechenhsin/bicycle_data.csv', index_col='Date',parse_dates=True)

# %%
df
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2022-09-30 19:00:00                 168.0                          57.0
# 2022-09-30 20:00:00                  73.0                          33.0
# 2022-09-30 21:00:00                  69.0                          30.0
# 2022-09-30 22:00:00                  51.0                          10.0
# 2022-09-30 23:00:00                  59.0                          22.0
#
#                      Fremont Bridge West Sidewalk
# Date
# ...

# %%
df.plot()

# %%
df.resample('W').sum().plot()

# %%
#background
import matplotlib.pyplot as plt  
plt.style.use('seaborn')


df.resample('W').sum().plot()

# %% [markdown]
# # Add columns to the dataframe containing

# %% [markdown]
# The total (East + West) bicycle count

# %%
df['Total (East + West) ']=df['Fremont Bridge East Sidewalk']+df['Fremont Bridge West Sidewalk']

# %%
df
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2022-09-30 19:00:00                 168.0                          57.0
# 2022-09-30 20:00:00                  73.0                          33.0
# 2022-09-30 21:00:00                  69.0                          30.0
# 2022-09-30 22:00:00                  51.0                          10.0
# 2022-09-30 23:00:00                  59.0                          22.0
#
#                      Fremont Bridge West Sidewalk  Total (East + West)
# Date
# ...

# %%
df.plot()

# %%
import matplotlib.pyplot as plt  
plt.style.use('seaborn')

df.resample('W').sum().plot()

# %%
df.resample('D').sum().rolling(365).sum().plot()

# %% [markdown]
# The hour of the day

# %%
df2 = pd.read_csv('/Users/leechenhsin/bicycle_data.csv')

# %%
df2
# Out:
#                          Date  Fremont Bridge Total  \
# 0      10/03/2012 12:00:00 AM                  13.0
# 1      10/03/2012 01:00:00 AM                  10.0
# 2      10/03/2012 02:00:00 AM                   2.0
# 3      10/03/2012 03:00:00 AM                   5.0
# 4      10/03/2012 04:00:00 AM                   7.0
# ...                       ...                   ...
# 87595  09/30/2022 07:00:00 PM                 168.0
# 87596  09/30/2022 08:00:00 PM                  73.0
# 87597  09/30/2022 09:00:00 PM                  69.0
# 87598  09/30/2022 10:00:00 PM                  51.0
# 87599  09/30/2022 11:00:00 PM                  59.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 0                               4.0                           9.0
# 1                               4.0                           6.0
# 2                               1.0                           1.0
# 3                               2.0                           3.0
# ...

# %%
#pd.to_datetime, astype(str)
df2['Date']=pd.to_datetime(df2['Date'].astype(str).str[0:19], format="%m/%d/%Y %H:%M:%S")

# %%
df2['Hour']=df2['Date'].dt.hour

# %% [markdown]
# The year

# %%
df2['Year']=df2['Date'].dt.year

# %%
df2
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0     2012-10-03 12:00:00                  13.0                           4.0
# 1     2012-10-03 01:00:00                  10.0                           4.0
# 2     2012-10-03 02:00:00                   2.0                           1.0
# 3     2012-10-03 03:00:00                   5.0                           2.0
# 4     2012-10-03 04:00:00                   7.0                           6.0
# ...                   ...                   ...                           ...
# 87595 2022-09-30 07:00:00                 168.0                          57.0
# 87596 2022-09-30 08:00:00                  73.0                          33.0
# 87597 2022-09-30 09:00:00                  69.0                          30.0
# 87598 2022-09-30 10:00:00                  51.0                          10.0
# 87599 2022-09-30 11:00:00                  59.0                          22.0
#
# ...

# %% [markdown]
# Create a new dataframe with the subset of data from the year 2016

# %%
df3=df2[df2['Year']==2016]

# %%
df3
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 28440 2016-01-01 12:00:00                  18.0                           9.0
# 28441 2016-01-01 01:00:00                  15.0                           3.0
# 28442 2016-01-01 02:00:00                  11.0                           6.0
# 28443 2016-01-01 03:00:00                   7.0                           1.0
# 28444 2016-01-01 04:00:00                   2.0                           0.0
# ...                   ...                   ...                           ...
# 37219 2016-12-31 07:00:00                  10.0                           6.0
# 37220 2016-12-31 08:00:00                   9.0                           3.0
# 37221 2016-12-31 09:00:00                  10.0                           4.0
# 37222 2016-12-31 10:00:00                  15.0                           7.0
# 37223 2016-12-31 11:00:00                   8.0                           4.0
#
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# For the dataframe in 3., use pandas + matplotlib to plot the counts by hour. (i.e. hour of the day on the x-axis, total daily counts on the y-axis

# %%
plt.bar(df3['Hour'],df3['Fremont Bridge Total'])
# Out:
# <BarContainer object of 8784 artists>

# %%
#plt.hist(x=df3['Hour'],bins=30)

# %%
#your_bins=100
#data=df3['Hour']
#arr=plt.hist(data,bins=your_bins)
#for i in range(your_bins):
    #plt.text(arr[1][i],arr[0][i],str(arr[0][i]))

# %% [markdown]
# Lastly, use python (and pandas) programming to computationally determine what is (on average) the busiest hour of the day
